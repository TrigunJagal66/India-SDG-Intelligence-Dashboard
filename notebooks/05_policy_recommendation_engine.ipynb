# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
master = pd.read_csv("../output/SDG_Master_Clustered.csv")

print(master.shape)

master.head()
# Out:
# (36, 135)
#                          state                             year  \
# 0  Andaman And Nicobar Islands  Calendar Year (Jan - Dec), 2020
# 1               Andhra Pradesh  Calendar Year (Jan - Dec), 2020
# 2            Arunachal Pradesh  Calendar Year (Jan - Dec), 2020
# 3                        Assam  Calendar Year (Jan - Dec), 2020
# 4                        Bihar  Calendar Year (Jan - Dec), 2020
#
#    sdg_india_index_no_poverty  sdg_india_index_zero_hunger  \
# 0                          71                           45
# 1                          81                           52
# 2                          54                           66
# 3                          51                           41
# 4                          32                           31
#
#    sdg_india_index_good_health_and_well_being  \
# 0                                          68
# 1                                          77
# 2                                          64
# 3                                          59
# 4                                          66
#
#    sdg_india_index_quality_education  sdg_india_index_gender_equality  \
# 0                                 57                               68
# 1                                 50                               58
# 2                                 41                               37
# 3                                 43                               25
# 4                                 29                               48
#
#    sdg_india_index_clean_water_and_sanitation  \
# 0                                          87
# 1                                          92
# 2                                          67
# 3                                          64
# 4                                          91
#
#    sdg_india_index_affordable_and_clean_energy  \
# 0                                          100
# 1                                          100
# 2                                           85
# 3                                           98
# 4                                           78
#
#    sdg_india_index_decent_work_and_economic_growth  \
# 0                                               59
# 1                                               67
# 2                                               50
# 3                                               50
# 4                                               50
#
#    sdg_india_index_industry_innovation_and_infrastructure  \
# 0                                                 23
# 1                                                 52
# 2                                                 31
# 3                                                 39
# 4                                                 24
#
#    sdg_india_index_reduced_inequality  \
# 0                                  67
# 1                                  74
# 2                                  69
# 3                                  65
# 4                                  48
#
#    sdg_india_index_sustainable_cities_and_communities  \
# 0                                                 85
# 1                                                 78
# 2                                                 39
# 3                                                 55
# 4                                                 67
#
#    sdg_india_index_responsible_consumption_and_production  \
# 0                                                 73
# 1                                                 84
# 2                                                 77
# 3                                                 66
# 4                                                 59
#
#    sdg_india_index_climate_action  sdg_india_index_life_on_land  \
# 0                              77                            72
# 1                              63                            69
# 2                              58                            93
# 3                              53                            78
# 4                              16                            62
#
#    sdg_india_index_peace_justice_and_strong_institutions  \
# 0                                                 46
# 1                                                 77
# 2                                                 64
# 3                                                 62
# 4                                                 73
#
#    composite_score_of_sdg_india_index  \
# 0                                  67
# 1                                  72
# 2                                  60
# 3                                  57
# 4                                  52
#
#    mean_shore_zone_coastal_water_quality_biochemical_oxygen_demand_bod  \
# 0                                                NaN
# 1                                               0.79
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    mean_shore_zone_coastal_water_quality_total_nitrogen_tn  \
# 0                                                NaN
# 1                                               40.5
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    increase_in_area_under_mangroves_percent  \
# 0                                       NaN
# 1                                       0.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    average_marine_acidity_ph_measured_at_representative_sampling_stations_in_the_shore_zone  \
# 0                                                NaN
# 1                                               8.07
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    potential_area_available_for_developed_under_aquaculture_percent  \
# 0                                                NaN
# 1                                          37.104023
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    population_living_below_the_national_poverty_line_percent  \
# 0                                               1.00
# 1                                               9.20
# 2                                              34.67
# 3                                              31.98
# 4                                              33.74
#
#    head_count_ratio_as_per_the_multidimensional_poverty_index_percent  \
# 0                                                6.9
# 1                                               15.6
# 2                                               24.4
# 3                                               36.2
# 4                                               52.5
#
#    households_with_any_usual_member_covered_by_a_health_scheme_or_health_insurance_percent  \
# 0                                                5.7
# 1                                               74.6
# 2                                               58.3
# 3                                               10.4
# 4                                               12.3
#
#    persons_provided_employment_to_the_persons_who_demanded_employment_under_mahatma_gandhi_national_rural_employment_guarantee_act_mgnrega_percent  \
# 0                                          82.961898
# 1                                          83.808651
# 2                                          95.435862
# 3                                          86.109387
# 4                                          78.599921
#
#    population_out_of_total_eligible_population_receiving_social_protection_benefits_under_pradhan_mantri_matru_vandana_yojana_pmmvy_and_child_development_percent  \
# 0                                              96.73
# 1                                              96.40
# 2                                              92.76
# 3                                              95.32
# 4                                              87.97
#
#    households_living_in_katcha_houses_percent  \
# 0                                         0.0
# 1                                         3.2
# 2                                        29.0
# 3                                         2.4
# 4                                         8.2
#
#    population_in_the_lowest_two_wealth_quintiles_percent  \
# 0                                               16.0
# 1                                               22.4
# 2                                               43.6
# 3                                               62.5
# 4                                               75.2
#
#    elected_women_over_total_seats_in_the_state_or_utlok_sabha_elections_percent  \
# 0                                               0.00
# 1                                              16.00
# 2                                               0.00
# 3                                               7.14
# 4                                               7.50
#
#    seats_held_by_women_in_panchayati_raj_institutions_percent  \
# 0                                              35.66
# 1                                              50.00
# 2                                              38.99
# 3                                              54.60
# 4                                              52.02
#
#    scheduled_caste_sc_or_scheduled_tribe_st_seats_in_state_legislative_assemblies_percent  \
# 0                                                NaN
# 1                                          20.571429
# 2                                          98.333333
# 3                                          19.047619
# 4                                          16.460905
#
#    ratio_of_transgender_to_male_labour_force_participation_rate_lfpr_5th_employment  \
# 0                                                NaN
# 1                                               0.99
# 2                                               1.39
# 3                                               0.60
# 4                                               0.59
#
#    rate_of_total_crimes_against_scheduled_caste_sc_per_1_00_000_sc_population  \
# 0                                                NaN
# 1                                               24.5
# 2                                                NaN
# 3                                                0.9
# 4                                               39.5
#
#    rate_of_total_crimes_against_scheduled_tribes_st_per_1_00_000_st_population  \
# 0                                               10.5
# 1                                               12.5
# 2                                                0.0
# 3                                                0.1
# 4                                                7.3
#
#    urban_households_living_in_katcha_houses_percent  \
# 0                                               0.0
# 1                                               0.7
# 2                                               8.9
# 3                                               0.4
# 4                                               1.1
#
#    deaths_due_to_road_accidents_in_urban_areas_per_1_00_000_population  \
# 0                                           4.166667
# 1                                          16.113744
# 2                                          11.764706
# 3                                          24.702038
# 4                                          21.629506
#
#    wards_with_100_percent_door_to_door_waste_collection_under_swachh_bharat_mission_urban_sbmu_percent  \
# 0                                         100.000000
# 1                                         100.000000
# 2                                          82.432432
# 3                                          87.910923
# 4                                          99.437370
#
#    household_toilets_constructed_against_target_percent  \
# 0                                              100.0
# 1                                              126.0
# 2                                               80.0
# 3                                               97.0
# 4                                              103.0
#
#    municipal_solid_wast_msw_processed_to_the_total_municipal_solid_wast_msw_generated_sbmu_percent  \
# 0                                          95.555556
# 1                                          63.670412
# 2                                          23.974763
# 3                                          63.244730
# 4                                          58.274648
#
#    wards_with_100_percent_source_segregation_sbm_u_percent  \
# 0                                         100.000000
# 1                                          96.802581
# 2                                          48.648649
# 3                                          42.735949
# 4                                          52.798342
#
#    installed_sewage_treatment_capacity_to_sewage_generated_in_urban_areas_percent  \
# 0                                           0.000000
# 1                                          18.640089
# 2                                           0.000000
# 3                                           0.107635
# 4                                           5.620609
#
#    urban_households_with_drainage_facility_percent  \
# 0                                             88.4
# 1                                             89.7
# 2                                             59.4
# 3                                             58.7
# 4                                             87.8
#
#    per_capita_fossil_fuel_consumption  \
# 0                               558.0
# 1                               158.4
# 2                               179.7
# 3                                88.0
# 4                                50.5
#
#    use_of_nitrogenous_fertilizer_out_of_total_n_p_k_nitrogen_phosphorous_potassium_percent  \
# 0                                          46.987952
# 1                                          59.575931
# 2                                           0.000000
# 3                                          66.643685
# 4                                          68.584991
#
#    hazardous_waste_generated_per_1_000_population_per1000populationperannum  \
# 0                                           0.000404
# 1                                          11.279270
# 2                                                NaN
# 3                                           1.337720
# 4                                           0.138161
#
#    quantity_of_hazardous_waste_recycled_or_utilized_to_total_hazardous_waste_generated_percent  \
# 0                                           0.000000
# 1                                          75.992319
# 2                                                NaN
# 3                                          20.915679
# 4                                          28.405407
#
#    plastic_waste_generated_per_1_000_population_implementation_of_plastic_waste_management_rules_2011_census_population_projections_per1000populationperannum  \
# 0                                           4.671717
# 1                                           1.274485
# 2                                           2.536752
# 3                                           0.948150
# 4                                           0.582283
#
#    biomedical_waste_treated_to_total_quality_of_biomedical_waste_generated_percent  \
# 0                                         100.000000
# 1                                         100.000000
# 2                                         100.000000
# 3                                          75.048046
# 4                                          28.834587
#
#    installed_capacity_of_grid_interactive_bio_power_per_10_lakh_population  \
# 0                                                NaN
# 1                                           9.635735
# 2                                           0.000000
# 3                                           0.057483
# 4                                           1.023012
#
#    human_lives_lost_per_1_crore_population_due_to_extreme_weather_events  \
# 0                                                NaN
# 1                                          15.567343
# 2                                         221.031480
# 3                                          15.568546
# 4                                                NaN
#
#    disaster_preparedness_score_as_per_disaster_resilience_index  \
# 0                                               20.5
# 1                                               19.5
# 2                                               11.5
# 3                                               23.0
# 4                                               19.5
#
#    renewable_energy_out_of_total_installed_generating_capacity_including_allocated_shares_percent  \
# 0                                          46.256039
# 1                                          40.725277
# 2                                          84.782451
# 3                                          32.272020
# 4                                           7.913385
#
#    co2_saved_from_light_emitting_diode_led_bulbs_per_1_000_population  \
# 0                                         104.930175
# 1                                          43.867585
# 2                                          34.185426
# 3                                          21.472451
# 4                                          16.646372
#
#    disability_adjusted_life_years_daly_rate_attributable_to_air_pollution_per_1_00_000_population  \
# 0                                                NaN
# 1                                             3007.0
# 2                                             1436.0
# 3                                             3464.0
# 4                                             4308.0
#
#    forest_covered_to_the_total_geographical_area_percent  \
# 0                                              81.74
# 1                                              17.88
# 2                                              79.63
# 3                                              36.11
# 4                                               7.76
#
#    tree_covered_to_the_geographical_area_percent  \
# 0                                           0.50
# 1                                           2.40
# 2                                           1.01
# 3                                           1.80
# 4                                           2.13
#
#    geographical_area_covered_by_forest_and_trees_percent  \
# 0                                              82.24
# 1                                              20.28
# 2                                              80.64
# 3                                              37.91
# 4                                               9.89
#
#    area_covered_under_afforestation_schemes_to_the_total_geographical_area_percent  \
# 0                                           0.086435
# 1                                           1.407694
# 2                                                NaN
# 3                                                NaN
# 4                                           0.372907
#
#    degraded_land_over_total_land_area_percent  \
# 0                                    6.416293
# 1                                   33.814958
# 2                                   11.736635
# 3                                    9.452268
# 4                                   12.655480
#
#    increase_in_area_of_desertification_percent  \
# 0                                          NaN
# 1                                     1.368330
# 2                                    12.617971
# 3                                    25.231950
# 4                                     5.347675
#
#    cases_under_wildlife_protection_act_1972_per_million_hectares_of_protected_area  \
# 0                                               13.0
# 1                                                5.0
# 2                                                4.0
# 3                                               63.0
# 4                                                9.0
#
#    murders_per_1_00_000_population  \
# 0                              3.3
# 1                              1.7
# 2                              4.0
# 3                              3.6
# 4                              2.6
#
#    cognizable_crimes_against_children_per_1_00_000_population  \
# 0                                              112.5
# 1                                               16.1
# 2                                               32.7
# 3                                               55.6
# 4                                               20.8
#
#    victims_of_human_trafficking_per_10_lakh_population  \
# 0                                           0.000000
# 1                                           7.626147
# 2                                           2.649007
# 3                                           7.205113
# 4                                           2.630922
#
#    missing_children_per_1_00_000_child_population  \
# 0                                       30.714286
# 1                                       17.523931
# 2                                        9.361702
# 3                                       11.858705
# 4                                       16.299687
#
#    courts_per_1_00_000_population  \
# 0                        0.000000
# 1                        1.211774
# 2                        2.715232
# 3                        1.350959
# 4                        1.581883
#
#    cases_under_prevention_of_corruption_act_and_related_sections_of_ipc_per_10_lakh_population  \
# 0                                           7.500000
# 1                                           2.350917
# 2                                           8.609272
# 3                                           0.522952
# 4                                           0.591125
#
#    births_registered_percent  population_covered_under_aadhaar_percent  \
# 0                       71.8                                      98.0
# 1                       90.2                                     100.0
# 2                      100.0                                      83.0
# 3                      100.0                                      45.0
# 4                       80.3                                      86.0
#
#    beneficiaries_covered_under_national_food_security_act_nfsa_2013_percent  \
# 0                                             100.00
# 1                                             100.00
# 2                                             100.00
# 3                                              94.27
# 4                                              99.85
#
#    children_who_are_underweight_under_five_years_of_age_percent  \
# 0                                                NaN
# 1                                               35.5
# 2                                               16.0
# 3                                               29.4
# 4                                               38.7
#
#    children_who_are_stunned_under_five_years_of_age_percent  \
# 0                                                NaN
# 1                                               31.5
# 2                                               28.0
# 3                                               32.4
# 4                                               42.0
#
#    anaemic_pregnant_women_in_the_age_group_of_15_to_49_years_percent  \
# 0                                               61.4
# 1                                               52.9
# 2                                               33.8
# 3                                               44.8
# 4                                               58.3
#
#    anaemic_adolescents_in_the_age_group_of_10_to_19_years_percent  \
# 0                                                NaN
# 1                                               21.7
# 2                                               26.4
# 3                                               36.9
# 4                                               28.1
#
#    rice_and_wheat_produced_annually_per_unit_area_directorate_of_economics_and_statistics_2018_19  \
# 0                                            2122.08
# 1                                            3729.47
# 2                                            1806.62
# 3                                            2147.44
# 4                                            2374.02
#
#    gross_value_added_constant_prices_in_agriculture_per_worker  \
# 0                                                NaN
# 1                                           0.731587
# 2                                           1.286107
# 3                                           0.620668
# 4                                           0.285550
#
#    maternal_mortality_ratio_per_1_00_000_live_births  \
# 0                                                NaN
# 1                                               65.0
# 2                                                NaN
# 3                                              215.0
# 4                                              149.0
#
#    mortality_rate_per_1_000_live_births_under_5_years_of_age  \
# 0                                                NaN
# 1                                               33.0
# 2                                                NaN
# 3                                               47.0
# 4                                               37.0
#
#    fully_immunized_children_in_the_age_group_of_9_to_11_months_percent  \
# 0                                               66.0
# 1                                               87.0
# 2                                               68.0
# 3                                               85.0
# 4                                               94.0
#
#    notification_rate_of_tuberculosis_cases_per_1_00_000_population  \
# 0                                                151
# 1                                                189
# 2                                                182
# 3                                                141
# 4                                                100
#
#    human_immunodeficiency_virus_hiv_incidence_per_1_000_uninfected_population  \
# 0                                               0.05
# 1                                               0.05
# 2                                               0.05
# 3                                               0.04
# 4                                               0.07
#
#    suicide_rate_per_1_00_000_population  \
# 0                                  45.5
# 1                                  12.4
# 2                                   7.4
# 3                                   6.9
# 4                                   0.5
#
#    death_rate_due_to_road_traffic_accidents_per_1_00_000_population  \
# 0                                           5.025126
# 1                                          15.261397
# 2                                           7.232913
# 3                                           9.428206
# 4                                           5.998468
#
#    institutional_deliveries_out_of_the_total_deliveries_reported_percent  \
# 0                                               98.2
# 1                                               99.6
# 2                                               89.6
# 3                                               91.1
# 4                                               84.8
#
#    monthly_per_capita_out_of_pocket_expenditure_on_health_as_a_share_of_monthly_per_capita_consumption_expenditure_mpce  \
# 0                                                7.0
# 1                                               13.5
# 2                                               17.0
# 3                                               12.9
# 4                                               14.5
#
#    number_of_physicians_nurses_and_midwives_per_10_000_population  \
# 0                                                NaN
# 1                                          95.143868
# 2                                          21.623816
# 3                                          22.571581
# 4                                          16.788101
#
#    adjusted_net_enrolment_ratio_aner_in_elementary_education_for_classes_1_to_8  \
# 0                                              74.10
# 1                                              87.98
# 2                                              80.98
# 3                                              96.36
# 4                                              86.54
#
#    average_annual_dropout_rate_at_secondary_level_for_classes_9_to_10  \
# 0                                              22.22
# 1                                              16.37
# 2                                              35.98
# 3                                              31.47
# 4                                              28.46
#
#    gross_enrolment_ratio_ger_in_higher_secondary_for_classes_11_to_12  \
# 0                                              56.44
# 1                                              46.84
# 2                                              38.48
# 3                                              30.94
# 4                                              26.39
#
#    students_in_grade_viii_achieving_atleast_a_minimum_proficiency_level_in_terms_of_nationally_defined_learning_outcomes_to_be_attained_by_the_pupils_at_the_end_of_the_grade_percent  \
# 0                                              65.50
# 1                                              80.15
# 2                                              59.95
# 3                                              79.55
# 4                                              78.30
#
#    gross_enrolment_ratio_ger_in_higher_education_in_the_age_group_of_18_to_23_years  \
# 0                                               23.2
# 1                                               32.4
# 2                                               29.7
# 3                                               18.7
# 4                                               13.6
#
#    persons_with_disability_completed_at_least_secondary_education_with_age_15_years_and_above_percent  \
# 0                                               28.5
# 1                                               15.4
# 2                                               10.3
# 3                                               16.8
# 4                                               18.5
#
#    gender_parity_index_gpi_for_higher_education_in_the_age_group_18_to_23_years  \
# 0                                               1.29
# 1                                               0.81
# 2                                               0.99
# 3                                               0.95
# 4                                               0.79
#
#    literate_persons_under_the_age_of_15_years_and_above_percent  \
# 0                                               88.3
# 1                                               65.6
# 2                                               79.9
# 3                                               84.9
# 4                                               64.7
#
#    schools_with_access_to_basic_infrastructure_such_as_electricity_drinking_water_percent  \
# 0                                          96.014493
# 1                                          91.259961
# 2                                          50.935935
# 3                                          59.513901
# 4                                          88.664016
#
#    trained_teachers_at_secondary_level_for_classes_9_to_10_percent  \
# 0                                          85.054773
# 1                                          75.176596
# 2                                          79.036496
# 3                                          29.294607
# 4                                          78.442195
#
#    pupil_teacher_ratio_ptr_at_secondary_level_for_classes_9_to_10  \
# 0                                               10.0
# 1                                               16.0
# 2                                               14.0
# 3                                               11.0
# 4                                               58.0
#
#    rate_of_crimes_against_women_per_1_00_000_female_population  \
# 0                                               72.2
# 1                                               67.9
# 2                                               43.3
# 3                                              177.8
# 4                                               32.3
#
#    sex_ratio_at_birth  \
# 0                 NaN
# 1               920.0
# 2                 NaN
# 3               925.0
# 4               895.0
#
#    ratio_of_female_to_male_average_wage_received_among_regular_wage_or_salaried_employees  \
# 0                                               0.95
# 1                                               0.71
# 2                                               0.56
# 3                                               0.53
# 4                                               0.75
#
#    per_lakh_women_who_have_experienced_cruelty_or_physical_violence_by_husband_or_his_relatives_during_the_year  \
# 0                                           0.526316
# 1                                          30.420811
# 2                                           7.397260
# 3                                          70.728242
# 4                                           4.583478
#
#    elected_women_over_total_seats_in_the_state_legislative_assembly_percent  \
# 0                                                NaN
# 1                                           8.000000
# 2                                           5.000000
# 3                                           6.349206
# 4                                          11.522634
#
#    ratio_of_female_to_male_labour_force_participation_rate_lfpr_in_the_age_group_of_15_to_59_years  \
# 0                                               0.39
# 1                                               0.55
# 2                                               0.26
# 3                                               0.17
# 4                                               0.06
#
#    proportion_of_women_in_managerial_positions_including_women_in_board_of_directors_in_listed_companies_per_1_000_persons  \
# 0                                                NaN
# 1                                              208.0
# 2                                                NaN
# 3                                              221.0
# 4                                              214.0
#
#    currently_married_women_with_satisfied_family_planning_methods_percent  \
# 0                                               73.0
# 1                                               93.6
# 2                                               50.0
# 3                                               55.6
# 4                                               51.4
#
#    operational_land_holding_gender_wise_percentage_of_female_operated_operational_holdings_percent  \
# 0                                          29.797557
# 1                                          30.086439
# 2                                          12.072969
# 3                                           1.668046
# 4                                          13.996113
#
#    rural_population_getting_safe_and_adequate_drinking_water_within_premises_through_pipe_water_supply_pws_percent  \
# 0                                          88.888889
# 1                                          68.518324
# 2                                          34.125099
# 3                                          25.699994
# 4                                          65.187443
#
#    rural_population_having_improved_source_of_drinking_water_percent  \
# 0                                         100.000000
# 1                                          99.811252
# 2                                          92.636580
# 3                                          74.724722
# 4                                          96.286309
#
#    individual_household_toilets_constructed_against_target_under_swachh_bharat_mission_gramin_percent  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    districts_verified_to_be_open_defication_free_odf_status_under_swachh_bharat_mission_gramin_percent  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    schools_with_separate_toilet_facility_for_girls_percent  \
# 0                                              99.28
# 1                                              97.28
# 2                                              70.12
# 3                                              75.30
# 4                                              97.92
#
#    industries_complying_with_wastewater_treatment_17_categories_of_highly_polluting_industries_or_grossly_polluting_or_red_category_of_industries_complying_with_wastewater_treatment_percent  \
# 0                                          60.000000
# 1                                          96.816976
# 2                                          70.893372
# 3                                          90.017212
# 4                                          96.844181
#
#    ground_water_withdrawal_against_availability_percent  \
# 0                                           3.030303
# 1                                          44.168734
# 2                                           0.374532
# 3                                          11.253092
# 4                                          45.739910
#
#    blocks_mandals_taluka_over_exploited_percent  \
# 0                                      0.000000
# 1                                      6.716418
# 2                                      0.000000
# 3                                      0.000000
# 4                                      2.247191
#
#    households_electrified_under_ministry_of_power_in_2019_percent  \
# 0                                                NaN
# 1                                              100.0
# 2                                              100.0
# 3                                              100.0
# 4                                              100.0
#
#    lpg_png_connections_against_number_of_households_as_per_mopng_calculations_as_on_31072020_percent  \
# 0                                         115.151515
# 1                                         101.157524
# 2                                          84.049080
# 3                                          97.605843
# 4                                          76.554045
#
#    annual_growth_rate_of_per_capita_gross_domestic_product_gdp_at_constant_prices  \
# 0                                                NaN
# 1                                           3.838030
# 2                                           2.516181
# 3                                           5.255325
# 4                                           7.628639
#
#    ease_of_doing_business_eodb_feedback_score  \
# 0                                        4.64
# 1                                       52.40
# 2                                        0.00
# 3                                        5.93
# 4                                        2.78
#
#    unemployment_rate_in_the_age_group_of_15_to_59_years_percent  \
# 0                                               13.8
# 1                                                5.7
# 2                                                7.7
# 3                                                7.1
# 4                                               10.6
#
#    labour_force_participation_rate_lfpr_percent_in_the_age_group_of_15_to_59_years  \
# 0                                               62.5
# 1                                               63.5
# 2                                               44.8
# 3                                               49.4
# 4                                               41.4
#
#    regular_wage_or_salaried_employees_in_non_agriculture_sector_without_any_social_security_benefit_percent  \
# 0                                               59.3
# 1                                               62.5
# 2                                               17.3
# 3                                               44.8
# 4                                               23.7
#
#    households_covered_with_a_bank_account_under_pmjdy_against_target_percent  \
# 0                                             100.00
# 1                                             100.00
# 2                                             100.00
# 3                                              99.96
# 4                                             100.00
#
#    functioning_branches_of_commercial_banks_per_1_00_000_population  \
# 0                                          18.796992
# 1                                          14.397612
# 2                                          11.826544
# 3                                           8.892593
# 4                                           6.372698
#
#    automated_teller_machines_atms_per_1_00_000_population  \
# 0                                          29.824561
# 1                                          21.008004
# 2                                          16.360053
# 3                                          11.600034
# 4                                           6.841954
#
#    women_account_holders_under_pradhan_mantri_jan_dhan_yojana_pmjdy_percent  \
# 0                                              47.94
# 1                                              59.31
# 2                                              55.05
# 3                                              59.26
# 4                                              56.22
#
#    targeted_habitations_connected_by_all_weather_roads_under_pradhan_mantri_gram_sadak_yojana_pmgsy  \
# 0                                           0.000000
# 1                                          98.460292
# 2                                          81.747270
# 3                                          94.376955
# 4                                          97.182163
#
#    share_of_gross_value_added_gva_in_manufacturing_to_total_gross_value_added_gva_in_current_prices_percent  \
# 0                                           1.089261
# 1                                           9.580831
# 2                                           3.200942
# 3                                          12.252417
# 4                                           7.213315
#
#    manufacturing_employment_as_a_percentage_of_total_employment_percent  \
# 0                                               7.19
# 1                                              10.60
# 2                                               2.05
# 3                                              10.55
# 4                                               5.30
#
#    innovation_score_as_per_the_india_innovation_index  \
# 0                                              18.89
# 1                                              24.19
# 2                                              14.90
# 3                                              16.38
# 4                                              14.48
#
#    score_as_per_logistics_ease_across_different_states_leads_report  \
# 0                                                NaN
# 1                                               3.42
# 2                                               2.77
# 3                                               3.00
# 4                                               2.85
#
#    mobile_connections_per_100_persons_mobile_tele_density_as_per_deptof_telecommunications  \
# 0                                              87.87
# 1                                              85.71
# 2                                              84.00
# 3                                              67.51
# 4                                              50.65
#
#    internet_subscribers_per_100_population_as_per_deptof_telecommunications  \
# 0                                                NaN
# 1                                              65.61
# 2                                              52.34
# 3                                              41.57
# 4                                              30.99
#
#    cluster
# 0        1
# 1        1
# 2        2
# 3        0
# 4        0

# %%
feature_direction = {

    # Poverty & Inequality (Lower is Better)
    "population_in_the_lowest_two_wealth_quintiles_percent": "negative",
    "head_count_ratio_as_per_the_multidimensional_poverty_index_percent": "negative",
    "population_living_below_the_national_poverty_line_percent": "negative",

    # Financial Inclusion (Higher is Better)
    "automated_teller_machines_atms_per_1_00_000_population": "positive",
    "functioning_branches_of_commercial_banks_per_1_00_000_population": "positive",

    # Connectivity (Higher is Better)
    "mobile_connections_per_100_persons_mobile_tele_density_as_per_deptof_telecommunications": "positive",
    "lpg_png_connections_against_number_of_households_as_per_mopng_calculations_as_on_31072020_percent": "positive",

    # Education (Higher is Better)
    "schools_with_access_to_basic_infrastructure_such_as_electricity_drinking_water_percent": "positive",
    "gross_enrolment_ratio_ger_in_higher_secondary_for_classes_11_to_12": "positive",
    "students_in_grade_viii_achieving_atleast_a_minimum_proficiency_level_in_terms_of_nationally_defined_learning_outcomes_to_be_attained_by_the_pupils_at_the_end_of_the_grade_percent": "positive",
    "gross_enrolment_ratio_ger_in_higher_education_in_the_age_group_of_18_to_23_years": "positive",
    "persons_with_disability_completed_at_least_secondary_education_with_age_15_years_and_above_percent": "positive",
    
    
    
    # Education (Lower is Better)
    
    
    "average_annual_dropout_rate_at_secondary_level_for_classes_9_to_10": "negative",

    # Health (Lower is Better)
    "maternal_mortality_ratio_per_1_00_000_live_births": "negative",
    "human_immunodeficiency_virus_hiv_incidence_per_1_000_uninfected_population": "negative",
    "anaemic_adolescents_in_the_age_group_of_10_to_19_years_percent": "negative",
    "mortality_rate_per_1_000_live_births_under_5_years_of_age": "negative",

    # Employment & Gender (Higher is Better)
    "ratio_of_female_to_male_labour_force_participation_rate_lfpr_in_the_age_group_of_15_to_59_years": "positive",
    "labour_force_participation_rate_lfpr_percent_in_the_age_group_of_15_to_59_years": "positive",
    "operational_land_holding_gender_wise_percentage_of_female_operated_operational_holdings_percent": "positive",

    # Environment & Sustainability
    "industries_complying_with_wastewater_treatment_17_categories_of_highly_polluting_industries_or_grossly_polluting_or_red_category_of_industries_complying_with_wastewater_treatment_percent": "positive",
    "per_capita_fossil_fuel_consumption": "negative",

    # Safety (Lower is Better)
    "deaths_due_to_road_accidents_in_urban_areas_per_1_00_000_population": "negative",
    "death_rate_due_to_road_traffic_accidents_per_1_00_000_population": "negative",

    # Economy (Higher is Better)
    "gross_value_added_constant_prices_in_agriculture_per_worker": "positive"
}

# %%
feature_names = {

    "population_in_the_lowest_two_wealth_quintiles_percent":
        "Population in Lowest Two Wealth Quintiles",

    "head_count_ratio_as_per_the_multidimensional_poverty_index_percent":
        "Multidimensional Poverty Index (MPI)",

    "population_living_below_the_national_poverty_line_percent":
        "Population Below Poverty Line",

    "automated_teller_machines_atms_per_1_00_000_population":
        "ATMs per 100,000 Population",

    "functioning_branches_of_commercial_banks_per_1_00_000_population":
        "Commercial Bank Branches",

    "mobile_connections_per_100_persons_mobile_tele_density_as_per_deptof_telecommunications":
        "Mobile Connections per 100 Persons",

    "schools_with_access_to_basic_infrastructure_such_as_electricity_drinking_water_percent":
        "Schools with Basic Infrastructure",

    "gross_enrolment_ratio_ger_in_higher_secondary_for_classes_11_to_12":
        "Higher Secondary Enrolment Ratio",

    "industries_complying_with_wastewater_treatment_17_categories_of_highly_polluting_industries_or_grossly_polluting_or_red_category_of_industries_complying_with_wastewater_treatment_percent":
        "Industries Complying with Wastewater Treatment",

    "maternal_mortality_ratio_per_1_00_000_live_births":
        "Maternal Mortality Ratio",

    "ratio_of_female_to_male_labour_force_participation_rate_lfpr_in_the_age_group_of_15_to_59_years":
        "Female to Male Labour Participation Ratio",

    "human_immunodeficiency_virus_hiv_incidence_per_1_000_uninfected_population":
        "HIV Incidence Rate",

    "anaemic_adolescents_in_the_age_group_of_10_to_19_years_percent":
        "Anaemic Adolescents",

    "average_annual_dropout_rate_at_secondary_level_for_classes_9_to_10":
        "Secondary School Dropout Rate",

    "students_in_grade_viii_achieving_atleast_a_minimum_proficiency_level_in_terms_of_nationally_defined_learning_outcomes_to_be_attained_by_the_pupils_at_the_end_of_the_grade_percent":
        "Grade VIII Learning Proficiency",

    "per_capita_fossil_fuel_consumption":
        "Per Capita Fossil Fuel Consumption",

    "gross_enrolment_ratio_ger_in_higher_education_in_the_age_group_of_18_to_23_years":
        "Higher Education Enrolment Ratio",

    "mortality_rate_per_1_000_live_births_under_5_years_of_age":
        "Under-5 Mortality Rate",

    "deaths_due_to_road_accidents_in_urban_areas_per_1_00_000_population":
        "Urban Road Accident Deaths",

    "persons_with_disability_completed_at_least_secondary_education_with_age_15_years_and_above_percent":
        "Secondary Education among Persons with Disability",

    "labour_force_participation_rate_lfpr_percent_in_the_age_group_of_15_to_59_years":
        "Labour Force Participation Rate",

    "operational_land_holding_gender_wise_percentage_of_female_operated_operational_holdings_percent":
        "Female Operated Land Holdings",

    "death_rate_due_to_road_traffic_accidents_per_1_00_000_population":
        "Road Traffic Accident Death Rate",

    "gross_value_added_constant_prices_in_agriculture_per_worker":
        "Agricultural Productivity per Worker",

    "lpg_png_connections_against_number_of_households_as_per_mopng_calculations_as_on_31072020_percent":
        "LPG/PNG Household Coverage"
}

# %%
recommendation_map = {

    # Poverty & Inequality
    "population_in_the_lowest_two_wealth_quintiles_percent":
        "Improve income generation opportunities and strengthen social welfare programs for economically weaker households.",

    "head_count_ratio_as_per_the_multidimensional_poverty_index_percent":
        "Improve access to healthcare, education, housing, sanitation, and other basic services.",

    "population_living_below_the_national_poverty_line_percent":
        "Strengthen poverty alleviation, livelihood generation, and employment programs.",

    # Financial Inclusion
    "automated_teller_machines_atms_per_1_00_000_population":
        "Increase ATM penetration and improve access to formal banking services.",

    "functioning_branches_of_commercial_banks_per_1_00_000_population":
        "Expand banking infrastructure and financial inclusion initiatives.",

    # Connectivity
    "mobile_connections_per_100_persons_mobile_tele_density_as_per_deptof_telecommunications":
        "Improve telecom infrastructure and digital connectivity.",

    "lpg_png_connections_against_number_of_households_as_per_mopng_calculations_as_on_31072020_percent":
        "Promote clean cooking fuel adoption and expand LPG/PNG coverage.",

    # Education
    "schools_with_access_to_basic_infrastructure_such_as_electricity_drinking_water_percent":
        "Improve school infrastructure, electricity access, drinking water, and sanitation facilities.",

    "gross_enrolment_ratio_ger_in_higher_secondary_for_classes_11_to_12":
        "Increase higher secondary school enrollment and retention.",

    "students_in_grade_viii_achieving_atleast_a_minimum_proficiency_level_in_terms_of_nationally_defined_learning_outcomes_to_be_attained_by_the_pupils_at_the_end_of_the_grade_percent":
        "Improve learning outcomes through teacher training and quality education initiatives.",

    "gross_enrolment_ratio_ger_in_higher_education_in_the_age_group_of_18_to_23_years":
        "Increase access to higher education and skill development opportunities.",

    "persons_with_disability_completed_at_least_secondary_education_with_age_15_years_and_above_percent":
        "Strengthen inclusive education and accessibility for persons with disabilities.",

    "average_annual_dropout_rate_at_secondary_level_for_classes_9_to_10":
        "Implement targeted interventions to reduce school dropout rates.",

    # Health
    "maternal_mortality_ratio_per_1_00_000_live_births":
        "Improve maternal healthcare services and institutional deliveries.",

    "human_immunodeficiency_virus_hiv_incidence_per_1_000_uninfected_population":
        "Expand HIV awareness, testing, prevention, and treatment programs.",

    "anaemic_adolescents_in_the_age_group_of_10_to_19_years_percent":
        "Strengthen nutrition programs and iron supplementation initiatives.",

    "mortality_rate_per_1_000_live_births_under_5_years_of_age":
        "Improve child healthcare, immunization, and nutrition services.",

    # Employment & Gender
    "ratio_of_female_to_male_labour_force_participation_rate_lfpr_in_the_age_group_of_15_to_59_years":
        "Promote women's workforce participation and economic empowerment.",

    "labour_force_participation_rate_lfpr_percent_in_the_age_group_of_15_to_59_years":
        "Create employment opportunities and strengthen workforce participation.",

    "operational_land_holding_gender_wise_percentage_of_female_operated_operational_holdings_percent":
        "Promote women's ownership and management of agricultural land and assets.",

    # Environment & Sustainability
    "industries_complying_with_wastewater_treatment_17_categories_of_highly_polluting_industries_or_grossly_polluting_or_red_category_of_industries_complying_with_wastewater_treatment_percent":
        "Improve industrial environmental compliance and wastewater treatment practices.",

    "per_capita_fossil_fuel_consumption":
        "Promote renewable energy adoption and improve energy efficiency.",

    # Safety
    "deaths_due_to_road_accidents_in_urban_areas_per_1_00_000_population":
        "Improve urban road safety infrastructure and traffic management systems.",

    "death_rate_due_to_road_traffic_accidents_per_1_00_000_population":
        "Strengthen road safety awareness, enforcement, and emergency response systems.",

    # Economy
    "gross_value_added_constant_prices_in_agriculture_per_worker":
        "Improve agricultural productivity through technology adoption and farmer support programs."
}

# %%
cluster_names = {

    0: "Development Challenge Cluster",

    1: "High Development Cluster",

    2: "North-East Development Cluster",

    3: "Unique Outlier Cluster"
}

# %%
top_features = list(feature_direction.keys())

print("Total Features:", len(top_features))
# Out:
# Total Features: 25

# %%
national_avg = master[top_features].mean()

national_avg.head()
# Out:
# population_in_the_lowest_two_wealth_quintiles_percent                 30.812500
# head_count_ratio_as_per_the_multidimensional_poverty_index_percent    19.509722
# population_living_below_the_national_poverty_line_percent             18.075286
# automated_teller_machines_atms_per_1_00_000_population                25.756383
# functioning_branches_of_commercial_banks_per_1_00_000_population      16.140302
# dtype: float64

# %%
def generate_state_report(state_name):

    if state_name not in master["state"].values:
        return {
            "error": "State not found"
        }

    state_row = master[
        master["state"] == state_name
    ].iloc[0]

    cluster = int(state_row["cluster"])

    cluster_name = cluster_names[cluster]

    composite_score = state_row[
        "composite_score_of_sdg_india_index"
    ]

    strengths = []
    weaknesses = []
    neutral = []

    for feature in top_features:

        state_value = state_row[feature]
        avg_value = national_avg[feature]

        threshold = avg_value * 0.10

        direction = feature_direction[feature]

        if direction == "positive":

            if state_value > avg_value + threshold:
                strengths.append(feature)

            elif state_value < avg_value - threshold:
                weaknesses.append(feature)

            else:
                neutral.append(feature)

        else:

            if state_value < avg_value - threshold:
                strengths.append(feature)

            elif state_value > avg_value + threshold:
                weaknesses.append(feature)

            else:
                neutral.append(feature)

    strength_details = []

    for feature in strengths:

        strength_details.append({

            "feature": feature,
            "name": feature_names[feature],
            "state_value": round(float(state_row[feature]), 2),
            "india_avg": round(float(national_avg[feature]), 2)

        })

    weakness_details = []

    for feature in weaknesses:

        weakness_details.append({

            "feature": feature,
            "name": feature_names[feature],
            "state_value": round(float(state_row[feature]), 2),
            "india_avg": round(float(national_avg[feature]), 2)

        })

    recommendations = list(
        set(
            recommendation_map[feature]
            for feature in weaknesses
        )
    )

    report = {

        "state": state_name,

        "cluster_id": cluster,

        "cluster": cluster_name,

        "composite_score": round(
            float(composite_score), 2
        ),

        "strength_count": len(strengths),

        "weakness_count": len(weaknesses),

        "neutral_count": len(neutral),

        "strengths": strength_details,

        "weaknesses": weakness_details,

        "recommendations": recommendations

    }

    return report

# %%
report = generate_state_report("Bihar")

report
# Out:
# {'state': 'Bihar',
#  'cluster_id': 0,
#  'cluster': 'Development Challenge Cluster',
#  'composite_score': 52.0,
#  'strength_count': 3,
#  'weakness_count': 18,
#  'neutral_count': 4,
#  'strengths': [{'feature': 'human_immunodeficiency_virus_hiv_incidence_per_1_000_uninfected_population',
#    'name': 'HIV Incidence Rate',
#    'state_value': 0.07,
#    'india_avg': 0.12},
#   {'feature': 'per_capita_fossil_fuel_consumption',
#    'name': 'Per Capita Fossil Fuel Consumption',
#    'state_value': 50.5,
#    'india_avg': 228.95},
#   {'feature': 'death_rate_due_to_road_traffic_accidents_per_1_00_000_population',
#    'name': 'Road Traffic Accident Death Rate',
#    'state_value': 6.0,
#    'india_avg': 10.32}],
#  'weaknesses': [{'feature': 'population_in_the_lowest_two_wealth_quintiles_percent',
#    'name': 'Population in Lowest Two Wealth Quintiles',
#    'state_value': 75.2,
#    'india_avg': 30.81},
#   {'feature': 'head_count_ratio_as_per_the_multidimensional_poverty_index_percent',
#    'name': 'Multidimensional Poverty Index (MPI)',
#    'state_value': 52.5,
#    'india_avg': 19.51},
#   {'feature': 'population_living_below_the_national_poverty_line_percent',
#    'name': 'Population Below Poverty Line',
#    'state_value': 33.74,
#    'india_avg': 18.08},
#   {'feature': 'automated_teller_machines_atms_per_1_00_000_population',
#    'name': 'ATMs per 100,000 Population',
#    'state_value': 6.84,
#    'india_avg': 25.76},
#   {'feature': 'functioning_branches_of_commercial_banks_per_1_00_000_population',
#    'name': 'Commercial Bank Branches',
#    'state_value': 6.37,
#    'india_avg': 16.14},
#   {'feature': 'mobile_connections_per_100_persons_mobile_tele_density_as_per_deptof_telecommunications',
#    'name': 'Mobile Connections per 100 Persons',
#    'state_value': 50.65,
#    'india_avg': 97.49},
#   {'feature': 'lpg_png_connections_against_number_of_households_as_per_mopng_calculations_as_on_31072020_percent',
#    'name': 'LPG/PNG Household Coverage',
#    'state_value': 76.55,
#    'india_avg': 104.87},
#   {'feature': 'gross_enrolment_ratio_ger_in_higher_secondary_for_classes_11_to_12',
#    'name': 'Higher Secondary Enrolment Ratio',
#    'state_value': 26.39,
#    'india_avg': 54.6},
#   {'feature': 'gross_enrolment_ratio_ger_in_higher_education_in_the_age_group_of_18_to_23_years',
#    'name': 'Higher Education Enrolment Ratio',
#    'state_value': 13.6,
#    'india_avg': 28.74},
#   {'feature': 'persons_with_disability_completed_at_least_secondary_education_with_age_15_years_and_above_percent',
#    'name': 'Secondary Education among Persons with Disability',
#    'state_value': 18.5,
#    'india_avg': 21.17},
#   {'feature': 'average_annual_dropout_rate_at_secondary_level_for_classes_9_to_10',
#    'name': 'Secondary School Dropout Rate',
#    'state_value': 28.46,
#    'india_avg': 17.27},
#   {'feature': 'maternal_mortality_ratio_per_1_00_000_live_births',
#    'name': 'Maternal Mortality Ratio',
#    'state_value': 149.0,
#    'india_avg': 112.58},
#   {'feature': 'anaemic_adolescents_in_the_age_group_of_10_to_19_years_percent',
#    'name': 'Anaemic Adolescents',
#    'state_value': 28.1,
#    'india_avg': 24.73},
#   {'feature': 'mortality_rate_per_1_000_live_births_under_5_years_of_age',
#    'name': 'Under-5 Mortality Rate',
#    'state_value': 37.0,
#    'india_avg': 31.61},
#   {'feature': 'ratio_of_female_to_male_labour_force_participation_rate_lfpr_in_the_age_group_of_15_to_59_years',
#    'name': 'Female to Male Labour Participation Ratio',
#    'state_value': 0.06,
#    'india_avg': 0.38},
#   {'feature': 'labour_force_participation_rate_lfpr_percent_in_the_age_group_of_15_to_59_years',
#    'name': 'Labour Force Participation Rate',
#    'state_value': 41.4,
#    'india_avg': 55.67},
#   {'feature': 'deaths_due_to_road_accidents_in_urban_areas_per_1_00_000_population',
#    'name': 'Urban Road Accident Deaths',
#    'state_value': 21.63,
#    'india_avg': 11.33},
#   {'feature': 'gross_value_added_constant_prices_in_agriculture_per_worker',
#    'name': 'Agricultural Productivity per Worker',
#    'state_value': 0.29,
#    'india_avg': 1.14}],
#  'recommendations': ['Expand banking infrastructure and financial inclusion initiatives.',
#   'Increase ATM penetration and improve access to formal banking services.',
#   'Improve child healthcare, immunization, and nutrition services.',
#   "Promote women's workforce participation and economic empowerment.",
#   'Create employment opportunities and strengthen workforce participation.',
#   'Improve access to healthcare, education, housing, sanitation, and other basic services.',
#   'Promote clean cooking fuel adoption and expand LPG/PNG coverage.',
#   'Implement targeted interventions to reduce school dropout rates.',
#   'Improve income generation opportunities and strengthen social welfare programs for economically weaker households.',
#   'Improve agricultural productivity through technology adoption and farmer support programs.',
#   'Improve maternal healthcare services and institutional deliveries.',
#   'Strengthen nutrition programs and iron supplementation initiatives.',
#   'Increase higher secondary school enrollment and retention.',
#   'Increase access to higher education and skill development opportunities.',
#   'Improve telecom infrastructure and digital connectivity.',
#   'Strengthen inclusive education and accessibility for persons with disabilities.',
#   'Strengthen poverty alleviation, livelihood generation, and employment programs.',
#   'Improve urban road safety infrastructure and traffic management systems.']}
